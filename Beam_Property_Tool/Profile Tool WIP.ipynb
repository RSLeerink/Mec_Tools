# %%
import pandas as pd

df = pd.read_excel('HEB_Profiles_S235_Eurocode_3.xlsx', index_col=0,header=1)  

df.head(5)

ProfileName = 'HEB100'

#df.set_index('Profile')

# %%
Profile_df = df.loc[ProfileName]
Profile_df
# Out:
# Depth                                                                     100
# Width                                                                     100
# Web thickness                                                               6
# Flange thickness                                                           10
# Root radius                                                                12
# Weight                                                                   20.4
# Perimeter                                                               0.567
# Area                                                                     2604
# Shear area z-z                                                            904
# Shear area y-y                                                           2000
# Second moment of area                                                   4.495
# Radius of gyration                                                       41.6
# ...

# %%
df.head(4)
# Out:
#         Depth Width Web thickness Flange thickness Root radius  Weight  \
# Profile
# NaN        h     b            tw               tf           r       m
# NaN      [mm]  [mm]          [mm]             [mm]        [mm]  [kg/m]
# NaN       NaN   NaN           NaN              NaN         NaN     NaN
# HEB100    100   100             6               10          12    20.4
#
#         Perimeter  Area  Shear area z-z  Shear area y-y   ...  \
# Profile                                                   ...
# NaN            P      A            Av,z            Av,y   ...
# NaN           [m]  [mm2]          [mm2]            [mm2]  ...
# NaN           NaN    NaN     (for η=1.2)             NaN  ...
# HEB100      0.567   2604             904            2000  ...
#
#         Design plastic shear force resistance y-y   \
# Profile
# NaN                                      Vpl,Rd,y
# NaN                                           [kN]
# NaN                                            NaN
# ...

# %%
df1 = Profile_df.reset_index()
df1
# Out:
#                                                 index  HEB100
# 0                                               Depth     100
# 1                                               Width     100
# 2                                       Web thickness       6
# 3                                    Flange thickness      10
# 4                                         Root radius      12
# 5                                              Weight    20.4
# 6                                           Perimeter   0.567
# 7                                               Area     2604
# 8                                     Shear area z-z      904
# 9                                     Shear area y-y     2000
# 10                             Second moment of area    4.495
# 11                                 Radius of gyration    41.6
# 12                           Elastic section modulus    89.91
# 13                           Plastic section modulus    104.2
# ...

# %%
16
# Out:
# 4495000.0

# %%
df.iloc[1][0]
# Out:
# '[mm]'

# %%
Profile_df[0]
# Out:
# 100
